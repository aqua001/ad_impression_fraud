# %% [markdown]
# # Detecting Fraud in Ad Impression Data
#
# I have a file with one day of impression logs for selected IP addresses. The nine fields
# are, in order:
#
# * Timestamp
# * IP address
# * Detected browser type
# * User agent string
# * Host (URL)
# * Whether the impression was in view (1.0 = yes, 0.0 = no)
# * Number of plugins installed
# * Browser window position and size (x, y, width, height)
# * Network latency
#
# My task is to identify hosts which are receiving a substantial amount of fraudulent
# traffic. As part of this, I may also wish to identify IP addresses home to machines that
# are part of botnets, but this is not required. The definition of "substantial" is up to me --
# this may be a ranked list of all hosts, or a list of hosts reaching a certain threshold, or I
# may choose not to quantify the amount of fraud and simply classify hosts as likely to be
# experiencing high fraud or not. To get started, I have a list of hosts which are known
# to receive substantial amounts of fraudulent traffic:
#
# * featureball.com
# * uvido.com
# * sprungliving.com
# * sweetboxgames.com
# * mammabay.co.uk
# * workingfathertv.com
# * worsthorrorgame.com
# * hourlyparent.com
# * ulterior-movies.com
# * myhomesdesign.com
# * indoorlife.tv
# * bumclub.info
# * psychoworld.tv
# * hunp.us
# * rlinevideos.com

# %%
import re
import math
import numpy as np
print 'numpy', np.__version__
import pandas as pd
print 'pandas', pd.__version__
import seaborn as sns
print 'seaborn', sns.__version__
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

pd.options.display.max_columns = 25

imp_df = pd.io.parsers.read_csv("ad_impression_data_set.tsv",sep='\t',
                                names=['Timestamp','IPadd','Browser','UserAgent','Host','Inview','Nplugins','Wpossize','Latency'],
                               header=None)
imp_df.head(5)
# Out:
# numpy 1.10.1
# pandas 0.17.0
# seaborn 0.6.0
#              Timestamp            IPadd        Browser  \
# 0  2014-08-25 00:00:00  393.414.443.469  Safari/Webkit
# 1  2014-08-25 00:00:00  393.414.443.469  Safari/Webkit
# 2  2014-08-25 00:00:00  325.441.386.395        Unknown
# 3  2014-08-25 00:00:00  325.441.386.395        Unknown
# 4  2014-08-25 00:00:00  325.441.386.395        Unknown
#
#                                            UserAgent  \
# 0  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 1  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 2  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 3  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 4  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
#
#                          Host  Inview  Nplugins        Wpossize  Latency
# 0    http://www.domain.com.au       0       NaN  (0,0,1280,629)        0
# 1    http://www.domain.com.au       0       NaN  (0,0,1280,629)        0
# 2  http://www.mangareader.net     NaN       NaN             NaN      NaN
# 3  http://www.mangareader.net     NaN       NaN             NaN      NaN
# 4  http://www.mangareader.net     NaN       NaN             NaN      NaN

# %%
print imp_df.describe()
# Out:
#               Inview       Nplugins         Latency
# count  211811.000000  162304.000000   200283.000000
# mean        0.431998      10.139442      345.200182
# std         0.495355       7.637172    13292.816593
# min         0.000000       1.000000        0.000000
# 25%         0.000000       2.000000        0.000000
# 50%         0.000000      10.000000       54.000000
# 75%         1.000000      15.000000      179.000000
# max         1.000000      61.000000  5866142.000000

# %%
def clean_hosts(data=None):
    ''' A bunch of regular expression magic to filter host names to the top level'''
    if data is None:
		raise ValueError("Input 'data' to clean_data is None")
    # deal with co.uk and com.au, convert to .couk and .comau, respectively (and other variants)
    data["Host"]=data["Host"].apply(lambda x: re.sub('(\.co)\.([a-z][a-z])$',r'\1\2',x))
    data["Host"]=data["Host"].apply(lambda x: re.sub('(\.com)\.([a-z][a-z])$',r'\1\2',x))
    # select just the top level and suffix
    data["Host"]=data["Host"].apply(lambda x: '.'.join(str(x).split('.')[-2:]))
    # account for cases like http://mlb.com (where there is only one '.')
    data["Host"]=data["Host"].apply(lambda x: str(x).split('//')[-1])
    
    #Remove ERROR Hosts
    print '\nNumber of ERROR hosts to be removed:', sum(data["Host"]=="ERROR"), '\n'
    data=data[data["Host"]!="ERROR"]
    return data

print imp_df.info()
print imp_df['Host'].head(5)
imp_df = clean_hosts(imp_df)
print imp_df.info()
print imp_df['Host'].head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234945 entries, 0 to 235082
# Data columns (total 9 columns):
# Timestamp    234945 non-null object
# IPadd        234945 non-null object
# Browser      234945 non-null object
# UserAgent    234945 non-null object
# Host         234945 non-null object
# Inview       211810 non-null float64
# Nplugins     162303 non-null float64
# Wpossize     118450 non-null object
# Latency      200279 non-null float64
# dtypes: float64(3), object(6)
# memory usage: 17.9+ MB
# None
# 0       domain.comau
# 1       domain.comau
# 2    mangareader.net
# 3    mangareader.net
# 4    mangareader.net
# Name: Host, dtype: object
#
# Number of ERROR hosts to be removed: 0
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234945 entries, 0 to 235082
# Data columns (total 9 columns):
# Timestamp    234945 non-null object
# IPadd        234945 non-null object
# Browser      234945 non-null object
# UserAgent    234945 non-null object
# Host         234945 non-null object
# Inview       211810 non-null float64
# Nplugins     162303 non-null float64
# Wpossize     118450 non-null object
# Latency      200279 non-null float64
# dtypes: float64(3), object(6)
# memory usage: 17.9+ MB
# None
# 0       domain.comau
# 1       domain.comau
# 2    mangareader.net
# 3    mangareader.net
# 4    mangareader.net
# Name: Host, dtype: object

# %%
fraudtraffic=['featureball.com',
'uvido.com',
'sprungliving.com',
'sweetboxgames.com',
'mammabay.couk', #had to modify because of how I cleaned above
'workingfathertv.com',
'worsthorrorgame.com',
'hourlyparent.com',
'ulterior-movies.com',
'myhomesdesign.com',
'indoorlife.tv',
'bumclub.info',
'psychoworld.tv',
'hunp.us',
'rlinevideos.com']

print "Host counts:\n", imp_df[imp_df["Host"].isin(fraudtraffic)]["Host"].value_counts()#.describe()
# Out:
# Host counts:
# uvido.com              692
# featureball.com        560
# sprungliving.com       228
# mammabay.couk          123
# workingfathertv.com    120
# worsthorrorgame.com     94
# hourlyparent.com        85
# ulterior-movies.com     83
# myhomesdesign.com       69
# indoorlife.tv           60
# bumclub.info            59
# hunp.us                 58
# psychoworld.tv          57
# rlinevideos.com         55
# Name: Host, dtype: int64

# %% [markdown]
# Yikes, we're missing one host, 'sweetboxgames.com'. By searching through the file, it appears there was a typo and the host name should be 'sweetxboxgames.com' (the 'x' was missing after 'sweet'). I will modify my `fraudtraffic` list to remedy this.

# %%
fraudtraffic=['featureball.com',
'uvido.com',
'sprungliving.com',
'sweetxboxgames.com', #fixed typo
'mammabay.couk', #had to modify because of how I cleaned above
'workingfathertv.com',
'worsthorrorgame.com',
'hourlyparent.com',
'ulterior-movies.com',
'myhomesdesign.com',
'indoorlife.tv',
'bumclub.info',
'psychoworld.tv',
'hunp.us',
'rlinevideos.com']

print "Host counts:\n", imp_df[imp_df["Host"].isin(fraudtraffic)]["Host"].value_counts()#.describe()
# Out:
# Host counts:
# uvido.com              692
# featureball.com        560
# sprungliving.com       228
# sweetxboxgames.com     150
# mammabay.couk          123
# workingfathertv.com    120
# worsthorrorgame.com     94
# hourlyparent.com        85
# ulterior-movies.com     83
# myhomesdesign.com       69
# indoorlife.tv           60
# bumclub.info            59
# hunp.us                 58
# psychoworld.tv          57
# rlinevideos.com         55
# Name: Host, dtype: int64

# %%
print imp_df.Browser.value_counts()
print imp_df.Browser.head(5)
print 'Chrome', imp_df.UserAgent.iloc[5]
print 'Safari', imp_df.UserAgent.iloc[0]
print 'IE', imp_df.UserAgent.iloc[20]
print 'Firefox', imp_df.UserAgent.iloc[38]
# Out:
# Chrome               76595
# Internet Explorer    63874
# Safari/Webkit        44093
# Firefox              28697
# Unknown              21599
# Opera                   87
# Name: Browser, dtype: int64
# 0    Safari/Webkit
# 1    Safari/Webkit
# 2          Unknown
# 3          Unknown
# 4          Unknown
# Name: Browser, dtype: object
# Chrome Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36
# Safari Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8) AppleWebKit/534.59.10 (KHTML, like Gecko) Version/5.1.9 Safari/534.59.10
# IE Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko
# Firefox Mozilla/5.0 (Windows NT 6.1; rv:32.0) Gecko/20100101 Firefox/32.0

# %%
import requests
#ua_string = imp_df.UserAgent.iloc[20]

def lookup_user_agent(ua_string):
    r = requests.post("http://www.useragentstring.com", data = {"uas":ua_string,"getJSON":'agent_name-agent_version'})
    return r.json()['agent_name']+'_'+r.json()['agent_version']

#print r.json()
#print r.json()['agent_name']
#print r.json()['agent_version']

#test_data = imp_df.iloc[0:20]
imp_df['UA_Browser_Ver']=imp_df["UserAgent"].apply(lambda x: lookup_user_agent(x))
#response = urllib2.urlopen(url).read()
#print response
#dat = simplejson.load(r.json())   
#print dat
#http://www.useragentstring.com/?uas=Mozilla/5.0%20%28Windows%20NT%206.1;%20WOW64;%20Trident/7.0;%20rv:11.0%29%20like%20Gecko&getJSON=agent_name-agent_version

# %%
test_data
# Out:
#               Timestamp            IPadd        Browser  \
# 0   2014-08-25 00:00:00  393.414.443.469  Safari/Webkit
# 1   2014-08-25 00:00:00  393.414.443.469  Safari/Webkit
# 2   2014-08-25 00:00:00  325.441.386.395        Unknown
# 3   2014-08-25 00:00:00  325.441.386.395        Unknown
# 4   2014-08-25 00:00:00  325.441.386.395        Unknown
# 5   2014-08-25 00:00:00  326.432.563.561         Chrome
# 6   2014-08-25 00:00:02  445.435.337.514        Unknown
# 7   2014-08-25 00:00:03  386.335.512.400  Safari/Webkit
# 8   2014-08-25 00:00:03  488.432.432.344         Chrome
# 9   2014-08-25 00:00:03  412.428.488.484         Chrome
# 10  2014-08-25 00:00:04  369.438.566.432         Chrome
# 11  2014-08-25 00:00:04  369.438.566.432         Chrome
# 12  2014-08-25 00:00:04  325.441.386.395        Unknown
# 13  2014-08-25 00:00:04  325.441.386.395        Unknown
# 14  2014-08-25 00:00:04  325.441.386.395        Unknown
# 15  2014-08-25 00:00:06  488.432.432.344         Chrome
# 16  2014-08-25 00:00:06  558.322.533.486  Safari/Webkit
# 17  2014-08-25 00:00:07  340.408.324.370  Safari/Webkit
# 18  2014-08-25 00:00:08  324.440.396.375         Chrome
# 19  2014-08-25 00:00:08  485.507.479.485        Unknown
#
#                                             UserAgent  \
# 0   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 1   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 2   Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 3   Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 4   Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 5   Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 6   Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 7   Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like ...
# 8   Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 9   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4)...
# 10  Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKi...
# 11  Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKi...
# 12  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 13  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 14  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 15  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 16  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4)...
# 17  Mozilla/5.0 (iPad; CPU OS 7_1_1 like Mac OS X)...
# 18  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 19  Mozilla/5.0 (Linux; Android 4.4.2; SM-G900V Bu...
#
#                         Host  Inview  Nplugins         Wpossize  Latency  \
# 0               domain.comau       0       NaN   (0,0,1280,629)        0
# 1               domain.comau       0       NaN   (0,0,1280,629)        0
# 2            mangareader.net     NaN       NaN              NaN      NaN
# 3            mangareader.net     NaN       NaN              NaN      NaN
# 4            mangareader.net     NaN       NaN              NaN      NaN
# 5            cheezburger.com       0        25   (0,0,1366,643)       73
# 6            cars-expert.com     NaN       NaN              NaN      NaN
# 7     lovepoemsandquotes.com       0         1  (0,0,1000,1163)        0
# 8                 bossip.com       1        23              NaN      386
# 9        adsafeprotected.com       0        12              NaN        0
# 10    stuffyoushouldknow.com       0        17   (0,0,1920,993)        0
# 11    stuffyoushouldknow.com       0        17   (0,0,1920,993)        0
# 12           mangareader.net     NaN       NaN              NaN      NaN
# 13           mangareader.net     NaN       NaN              NaN      NaN
# 14           mangareader.net     NaN       NaN              NaN      NaN
# 15           madamenoire.com       0        23   (0,0,1366,643)      139
# 16               wattpad.com       1         7              NaN       79
# 17  onegoodthingbyjillee.com       0         1              NaN        0
# 18                 about.com       1        15              NaN      166
# 19                   vh1.com     NaN       NaN              NaN      NaN
#
#                UA_Browser_Ver
# 0                Safari_5.1.9
# 1                Safari_5.1.9
# 2        Chrome_36.0.1985.143
# 3        Chrome_36.0.1985.143
# 4        Chrome_36.0.1985.143
# 5        Chrome_36.0.1985.143
# 6       Internet Explorer_9.0
# 7                  Safari_7.0
# 8        Chrome_36.0.1985.143
# 9        Chrome_36.0.1985.143
# 10       Chrome_36.0.1985.143
# 11       Chrome_36.0.1985.143
# 12       Chrome_36.0.1985.143
# 13       Chrome_36.0.1985.143
# 14       Chrome_36.0.1985.143
# 15       Chrome_36.0.1985.143
# 16               Safari_7.0.5
# 17                  Safari_--
# 18       Chrome_36.0.1985.143
# 19  Android Webkit Browser_--

# %% [markdown]
# ### Assumptions
# * logs are correct. I assume that when there are observations of one IP address clicking on the same host 3 times in a second, that this is what occurred. It may be the case that some entries are simply repeated due to errors in the recording.
# * ERROR hosts are to be disregarded. As there is no valid host, the only information is IP address and Browser/User Agent info
# * That greatboxgames.com should be greatxboxgames.com
#
# ### Cleaning and Feature Engineering
# * Remove ERROR hosts
# * Standardize hosts by removing preceeding 'http://www.|go.|video.'
# * Convert timestamp to seconds in the day
# * Create browser window area feature
# * Create inter-impression interval (III) feature

# %%
def clean_data(data=None):
    if data is None:
		raise ValueError("Input 'data' to clean_data is None")

    #Clean up some of the Host strings
    data["Host"] = data["Host"].apply(lambda x: str(x).replace("http://go.",""))
    data["Host"] = data["Host"].apply(lambda x: str(x).replace("http://video.",""))
    data["Host"] = data["Host"].apply(lambda x: str(x).replace("http://videos.",""))
    data["Host"] = data["Host"].apply(lambda x: str(x).replace("http://videos1.",""))
    data["Host"] = data["Host"].apply(lambda x: str(x).replace("http://vids.",""))
    data["Host"] = data["Host"].apply(lambda x: str(x).replace("http://pixel.",""))
    data["Host"] = data["Host"].apply(lambda x: str(x).replace("http://fw.",""))
    data["Host"] = data["Host"].apply(lambda x: str(x).replace("http://ad.",""))
    
    data["Host"] = data["Host"].apply(lambda x: str(x).replace("http://www.",""))
    data["Host"] = data["Host"].apply(lambda x: str(x).replace("http://",""))
    
    #Remove ERROR Hosts
    print 'Number of ERROR hosts:', sum(data["Host"]=="ERROR")
    data=data[data["Host"]!="ERROR"]
    return data
   
def timestamp_to_secs(x):
    #Converts timestamp to seconds in the day
    return int(x[11:13])*3600  + int(x[-5:-3])*60 + int(x[-2:])

def window_area(x):
    #Multiplies the width and height of the window
    val=np.NAN
    if isinstance(x,str):
        [xp,yp,w,h]=x[1:-1].split(',')
        val=int(w)*int(h)
    return val

# %%
def timestamp_to_secs(x):
    return int(x[11:13])*3600  + int(x[-5:-3])*60 + int(x[-2:])
      
#Add column that converts timestamp to time of day, in seconds
data["Tsecs"]=data["Timestamp"].apply(lambda x: timestamp_to_secs(x))

#Clean up some of the Host strings
data["Host"] = data["Host"].apply(lambda x: str(x).replace("http://go.",""))
data["Host"] = data["Host"].apply(lambda x: str(x).replace("http://video.",""))
data["Host"] = data["Host"].apply(lambda x: str(x).replace("http://videos.",""))
data["Host"] = data["Host"].apply(lambda x: str(x).replace("http://vids.",""))
data["Host"] = data["Host"].apply(lambda x: str(x).replace("http://www.",""))
data["Host"] = data["Host"].apply(lambda x: str(x).replace("http://",""))

#Remove ERROR Hosts
print sum(data["Host"]=="ERROR")
data=data[data["Host"]!="ERROR"]
print sum(data["Host"]=="ERROR")

#Multiplies the width and height of the window
def window_area(x):
    val=np.NAN
    if isinstance(x,str):
        [xp,yp,w,h]=x[1:-1].split(',')
        val=int(w)*int(h)
    return val

#Add column that contains browser window area
data["Bwinarea"] = data["Bwinpossize"].apply(lambda x: window_area(x))
# Out:
# 138
# 0

# %%
fraudtraffic=["featureplay.com","uvidi.com","spryliving.com","greatxboxgames.com",
              "mmabay.co.uk","workingmothertv.com","besthorrorgame.com","dailyparent.com","superior-movies.com",
              "yourhousedesign.com","outdoorlife.tv","drumclub.info","cycleworld.tv","hmnp.us","nlinevideos.com"]

print "IP counts:\n", data[data["Host"].isin(fraudtraffic)]["IPadd"].value_counts().describe()
print "Host counts:\n", data[data["Host"].isin(fraudtraffic)]["Host"].value_counts().describe()

fdata = data[data["Host"].isin(fraudtraffic)]
nfdata = data[~data["Host"].isin(fraudtraffic)]

f, axs = plt.subplots(1, 2)
fdata["Tsecs"].value_counts(normalize=True).plot(kind='bar',ax=axs[0])
axs[0].set_title('Seconds (fraud)')
nfdata["Tsecs"].value_counts(normalize=True).plot(kind='bar',ax=axs[1])
axs[1].set_title('Seconds (nonfraud)')

# %%
#Reduce the data - Remove Hosts that are present less than 8 times
host_counts = data["Host"].value_counts()
host_counts
host_counts.describe()
sighost_counts = host_counts[host_counts>8]
keepHosts = sighost_counts.index.map(lambda x: str(x))
data = data[data["Host"].isin(keepHosts)]


#Reduce the data - Remove IPs that are present less than 17 times
IP_counts = data["IPadd"].value_counts()
IP_counts
IP_counts.describe()
sigIP_counts = IP_counts[IP_counts>17]
keepIPs = sigIP_counts.index.map(lambda x: str(x))
data = data[data["IPadd"].isin(keepIPs)]
# Out:
# 805120
# C:\Users\btq\Anaconda\lib\site-packages\IPython\kernel\__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data
# Out:
#                   Timestamp            IPadd            Browser  \
# 0       2014-08-25 00:00:00  393.414.443.469      Safari/Webkit
# 1       2014-08-25 00:00:00  393.414.443.469      Safari/Webkit
# 2       2014-08-25 00:00:00  325.441.386.395            Unknown
# 3       2014-08-25 00:00:00  325.441.386.395            Unknown
# 4       2014-08-25 00:00:00  325.441.386.395            Unknown
# 5       2014-08-25 00:00:00  326.432.563.561             Chrome
# 6       2014-08-25 00:00:02  445.435.337.514            Unknown
# 7       2014-08-25 00:00:03  386.335.512.400      Safari/Webkit
# 8       2014-08-25 00:00:03  488.432.432.344             Chrome
# 9       2014-08-25 00:00:03  412.428.488.484             Chrome
# 10      2014-08-25 00:00:04  369.438.566.432             Chrome
# 11      2014-08-25 00:00:04  369.438.566.432             Chrome
# 12      2014-08-25 00:00:04  325.441.386.395            Unknown
# 13      2014-08-25 00:00:04  325.441.386.395            Unknown
# 14      2014-08-25 00:00:04  325.441.386.395            Unknown
# 15      2014-08-25 00:00:06  488.432.432.344             Chrome
# 16      2014-08-25 00:00:06  558.322.533.486      Safari/Webkit
# 17      2014-08-25 00:00:07  340.408.324.370      Safari/Webkit
# 18      2014-08-25 00:00:08  324.440.396.375             Chrome
# 19      2014-08-25 00:00:08  485.507.479.485            Unknown
# 20      2014-08-25 00:00:09  369.336.335.527  Internet Explorer
# 21      2014-08-25 00:00:09  488.432.432.344             Chrome
# 22      2014-08-25 00:00:09  325.554.366.399             Chrome
# 23      2014-08-25 00:00:10  569.400.374.337             Chrome
# 24      2014-08-25 00:00:10  412.428.488.484             Chrome
# 25      2014-08-25 00:00:10  375.326.337.448             Chrome
# 26      2014-08-25 00:00:11  386.335.512.400      Safari/Webkit
# 27      2014-08-25 00:00:11  488.432.432.344             Chrome
# 28      2014-08-25 00:00:11  326.432.563.561             Chrome
# 29      2014-08-25 00:00:12  445.435.337.514  Internet Explorer
# ...                     ...              ...                ...
# 235053  2014-08-25 23:59:42  378.416.501.388             Chrome
# 235054  2014-08-25 23:59:43  569.534.355.485      Safari/Webkit
# 235055  2014-08-25 23:59:43  544.507.561.570  Internet Explorer
# 235056  2014-08-25 23:59:43  325.447.518.517  Internet Explorer
# 235057  2014-08-25 23:59:43  485.327.497.402      Safari/Webkit
# 235058  2014-08-25 23:59:44  441.340.569.346             Chrome
# 235059  2014-08-25 23:59:45  432.514.464.517            Firefox
# 235060  2014-08-25 23:59:45  485.377.574.353            Unknown
# 235061  2014-08-25 23:59:46  485.377.574.353            Unknown
# 235062  2014-08-25 23:59:47  508.436.455.358      Safari/Webkit
# 235063  2014-08-25 23:59:47  496.414.405.323      Safari/Webkit
# 235064  2014-08-25 23:59:47  325.407.571.466      Safari/Webkit
# 235065  2014-08-25 23:59:50  508.436.455.358            Unknown
# 235066  2014-08-25 23:59:50  496.395.509.457      Safari/Webkit
# 235067  2014-08-25 23:59:50  519.387.390.372             Chrome
# 235068  2014-08-25 23:59:51  508.436.455.358            Unknown
# 235069  2014-08-25 23:59:51  544.507.561.570  Internet Explorer
# 235070  2014-08-25 23:59:52  569.468.562.430             Chrome
# 235071  2014-08-25 23:59:52  544.507.561.570  Internet Explorer
# 235072  2014-08-25 23:59:52  529.445.376.393             Chrome
# 235073  2014-08-25 23:59:53  369.536.532.416             Chrome
# 235074  2014-08-25 23:59:54  441.340.569.346             Chrome
# 235075  2014-08-25 23:59:54  544.507.561.570  Internet Explorer
# 235076  2014-08-25 23:59:55  441.340.569.346             Chrome
# 235077  2014-08-25 23:59:55  325.470.546.528            Firefox
# 235078  2014-08-25 23:59:55  325.461.566.544      Safari/Webkit
# 235079  2014-08-25 23:59:56  325.461.566.544      Safari/Webkit
# 235080  2014-08-25 23:59:56  325.461.566.544            Unknown
# 235081  2014-08-25 23:59:58  558.486.391.452             Chrome
# 235082  2014-08-25 23:59:58  326.432.487.575      Safari/Webkit
#
#                                                     UserA  \
# 0       Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 1       Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 2       Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 3       Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 4       Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 5       Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 6       Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 7       Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like ...
# 8       Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 9       Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4)...
# 10      Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKi...
# 11      Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKi...
# 12      Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 13      Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 14      Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 15      Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 16      Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4)...
# 17      Mozilla/5.0 (iPad; CPU OS 7_1_1 like Mac OS X)...
# 18      Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 19      Mozilla/5.0 (Linux; Android 4.4.2; SM-G900V Bu...
# 20      Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7....
# 21      Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 22      Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKi...
# 23      Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...
# 24      Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4)...
# 25      Mozilla/5.0 (Windows NT 6.0) AppleWebKit/537.3...
# 26      Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like ...
# 27      Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 28      Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 29      Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# ...                                                   ...
# 235053  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 235054  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4)...
# 235055  Mozilla/5.0 (compatible; MSIE 10.0; Windows NT...
# 235056  Mozilla/4.0 (compatible; MSIE 7.0; Windows NT ...
# 235057  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 235058  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 235059  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
# 235060  Mozilla/5.0 (iPad; CPU OS 6_1_3 like Mac OS X)...
# 235061  Mozilla/5.0 (iPad; CPU OS 6_1_3 like Mac OS X)...
# 235062  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4)...
# 235063  Mozilla/5.0 (iPod; CPU iPhone OS 6_1_6 like Ma...
# 235064  Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like ...
# 235065  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4)...
# 235066  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4)...
# 235067  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...
# 235068  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4)...
# 235069  Mozilla/5.0 (compatible; MSIE 10.0; Windows NT...
# 235070  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...
# 235071  Mozilla/5.0 (compatible; MSIE 10.0; Windows NT...
# 235072  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 235073  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 235074  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 235075  Mozilla/5.0 (compatible; MSIE 10.0; Windows NT...
# 235076  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 235077  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
# 235078  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4)...
# 235079  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4)...
# 235080  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4)...
# 235081  Mozilla/5.0 (X11; CrOS x86_64 5841.98.0) Apple...
# 235082  Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like ...
#
#                                     Host  Iinview  Nplugins      Bwinpossize  \
# 0                          domain.com.au        0       NaN   (0,0,1280,629)
# 1                          domain.com.au        0       NaN   (0,0,1280,629)
# 2                        mangareader.net      NaN       NaN              NaN
# 3                        mangareader.net      NaN       NaN              NaN
# 4                        mangareader.net      NaN       NaN              NaN
# 5               failblog.cheezburger.com        0        25   (0,0,1366,643)
# 6                        cars-expert.com      NaN       NaN              NaN
# 7                 lovepoemsandquotes.com        0         1  (0,0,1000,1163)
# 8                         ads.bossip.com        1        23              NaN
# 9                 fw.adsafeprotected.com        0        12              NaN
# 10                stuffyoushouldknow.com        0        17   (0,0,1920,993)
# 11                stuffyoushouldknow.com        0        17   (0,0,1920,993)
# 12                       mangareader.net      NaN       NaN              NaN
# 13                       mangareader.net      NaN       NaN              NaN
# 14                       mangareader.net      NaN       NaN              NaN
# 15                       madamenoire.com        0        23   (0,0,1366,643)
# 16                           wattpad.com        1         7              NaN
# 17              onegoodthingbyjillee.com        0         1              NaN
# 18                 collegeapps.about.com        1        15              NaN
# 19                             m.vh1.com      NaN       NaN              NaN
# 20                              ebay.com        1         2              NaN
# 21                        ads.bossip.com        1        23              NaN
# 22                   jobsearch.about.com        1        16   (0,0,1366,643)
# 23                fw.adsafeprotected.com        1         8              NaN
# 24                fw.adsafeprotected.com        0        12              NaN
# 25                     supply.upjers.com        1        21              NaN
# 26                lovepoemsandquotes.com        0         1  (0,0,1000,1163)
# 27                       madamenoire.com        1        23   (0,0,1366,643)
# 28              failblog.cheezburger.com        0        25   (0,0,1366,643)
# 29                      allsports247.com        1       NaN              NaN
# ...                                  ...      ...       ...              ...
# 235053               businessinsider.com        1        21   (0,0,1280,939)
# 235054                          ebay.com        1         7              NaN
# 235055                       eonline.com        1       NaN              NaN
# 235056              web.mail.comcast.net        1       NaN        (0,0,0,0)
# 235057                   styleblazer.com        0        13    (0,0,936,548)
# 235058            fw.adsafeprotected.com        0        15              NaN
# 235059                     viralnova.com        0        21   (0,0,1366,577)
# 235060         pixel.adsafeprotected.com      NaN       NaN              NaN
# 235061         pixel.adsafeprotected.com      NaN       NaN              NaN
# 235062                teaching.about.com        1        11              NaN
# 235063                 marthastewart.com        0         1              NaN
# 235064         pixel.adsafeprotected.com        0         1     (0,0,320,50)
# 235065              iwastesomuchtime.com      NaN       NaN              NaN
# 235066            fw.adsafeprotected.com        1         9              NaN
# 235067  sistemasoperativos.angelfire.com        1         7   (0,0,1280,923)
# 235068              iwastesomuchtime.com      NaN       NaN              NaN
# 235069                       eonline.com        0       NaN              NaN
# 235070                      brainjet.com        1         9   (0,0,1280,675)
# 235071                       eonline.com        0       NaN   (0,0,1280,530)
# 235072                         about.com        0        18              NaN
# 235073                         about.com        1        22              NaN
# 235074            fw.adsafeprotected.com        0        15              NaN
# 235075                       eonline.com        1       NaN              NaN
# 235076            fw.adsafeprotected.com        0        15              NaN
# 235077                        pronto.com        1        17  (0,0,1638,1021)
# 235078            fw.adsafeprotected.com        1         7              NaN
# 235079         pixel.adsafeprotected.com        1         7              NaN
# 235080         pixel.adsafeprotected.com      NaN       NaN              NaN
# 235081                       realtor.com        1         9              NaN
# 235082                     viralnova.com        0         1    (0,0,320,372)
#
#         NetLat  Tsecs  Bwinarea
# 0            0      0    805120
# 1            0      0    805120
# 2          NaN      0       NaN
# 3          NaN      0       NaN
# 4          NaN      0       NaN
# 5           73      0    878338
# 6          NaN      2       NaN
# 7            0      3   1163000
# 8          386      3       NaN
# 9            0      3       NaN
# 10           0      4   1906560
# 11           0      4   1906560
# 12         NaN      4       NaN
# 13         NaN      4       NaN
# 14         NaN      4       NaN
# 15         139      6    878338
# 16          79      6       NaN
# 17           0      7       NaN
# 18         166      8       NaN
# 19         NaN      8       NaN
# 20          81      9       NaN
# 21         731      9       NaN
# 22           0      9    878338
# 23         505     10       NaN
# 24           0     10       NaN
# 25          93     10       NaN
# 26         NaN     11   1163000
# 27         340     11    878338
# 28         211     11    878338
# 29           0     12       NaN
# ...        ...    ...       ...
# 235053     372  86382   1201920
# 235054     478  86383       NaN
# 235055      94  86383       NaN
# 235056       0  86383         0
# 235057       0  86383    512928
# 235058       0  86384       NaN
# 235059       0  86385    788182
# 235060     NaN  86385       NaN
# 235061     NaN  86386       NaN
# 235062     128  86387       NaN
# 235063       0  86387       NaN
# 235064       0  86387     16000
# 235065     NaN  86390       NaN
# 235066     122  86390       NaN
# 235067     102  86390   1181440
# 235068     NaN  86391       NaN
# 235069       0  86391       NaN
# 235070       0  86392    864000
# 235071     105  86392    678400
# 235072     NaN  86392       NaN
# 235073      66  86393       NaN
# 235074     NaN  86394       NaN
# 235075       0  86394       NaN
# 235076       0  86395       NaN
# 235077       0  86395   1672398
# 235078      92  86395       NaN
# 235079     402  86396       NaN
# 235080     NaN  86396       NaN
# 235081     170  86398       NaN
# 235082       0  86398    119040
#
# [234945 rows x 11 columns]
